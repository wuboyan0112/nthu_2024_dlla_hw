# %% [markdown]
# <div align="center">
#
# #### Lab 3
#
# # National Tsing Hua University
#
# #### Spring 2024
#
# #### 11220IEEM 513600
#
# #### Deep Learning and Industrial Applications
#
# ## Lab 3: Anomaly Detection in Industrial Applications
#
# </div>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Introduction
#
# In today's industrial landscape, the ability to detect anomalies in manufacturing processes and products is critical for maintaining quality, efficiency, and safety. This lab focuses on leveraging deep learning techniques for anomaly detection in various industrial applications, using the MVTEC Anomaly Detection Dataset. By employing ImageNet-pretrained models available in torchvision, students will gain hands-on experience in classfying defects and irregularities across different types of industrial products.
#
# Throughout this lab, you'll be involved in the following key activities:
# - Explore and process the MVTec Anomaly Detection Dataset.
# - Apply ImageNet-pretrained models from [Torchvision](https://pytorch.org/vision/stable/models.html) to detect anomalies in industrial products.
# - Evaluate the performance of the models to understand their effectiveness in real-world industrial applications.
#
# ### Objectives
#
# - Understand the principles of anomaly detection in the context of industrial applications.
# - Learn how to implement and utilize ImageNet-pretrained models for detecting anomalies.
# - Analyze and interpret the results of the anomaly detection models to assess their practicality in industrial settings.
#
# ### Dataset
#
# The MVTec AD Dataset is a comprehensive collection of high-resolution images across different categories of industrial products, such as bottles, cables, and metal nuts, each with various types of defects. This dataset is pivotal for developing and benchmarking anomaly detection algorithms. You can download our lab's dataset [here](https://drive.google.com/file/d/19600hUOpx0hl78TdpdH0oyy-gGTk_F_o/view?usp=share_link). You can drop downloaded data and drop to colab, or you can put into yor google drive.
#
# ### References
# - [MVTec AD Dataset](https://www.kaggle.com/datasets/ipythonx/mvtec-ad/data) for the dataset used in this lab.
# - [Torchvision Models](https://pytorch.org/vision/stable/models.html) for accessing ImageNet-pretrained models to be used in anomaly detection tasks.
# - [State-of-the-Art Anomaly Detection on MVTec AD](https://paperswithcode.com/sota/anomaly-detection-on-mvtec-ad) for insights into the latest benchmarks and methodologies in anomaly detection applied to the MVTec AD dataset.
# - [CVPR 2019: MVTec AD — A Comprehensive Real-World Dataset for Unsupervised Anomaly Detection] for the original paper of MVTec AD dataset.

# %%
import glob
import matplotlib.pyplot as plt
import random
from tqdm.auto import tqdm
import cv2
import numpy as np

# %%
from google.colab import drive

drive.mount('/content/drive')

# !tar -xvf drive/MyDrive/cable.tar.gz cable
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# tar: drive/MyDrive/cable.tar.gz: Cannot open: No such file or directory
# tar: Error is not recoverable: exiting now

# %%
file_paths = glob.glob('/content/drive/MyDrive/toothbrush/test/*/*.png')
file_paths = sorted([path for path in file_paths if path.split('/')[-1] in [f'{i:03}.png' for i in range(10)]])

# %%
all_data = []

for img in tqdm(file_paths):
    img = cv2.imread(img)
    img = img[..., ::-1]
    all_data.append(img)

all_data = np.stack(all_data)
print(all_data.shape)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# (20, 1024, 1024, 3)

# %%
import matplotlib.pyplot as plt
import numpy as np

classes = sorted(set([path.split('/')[-2] for path in file_paths]))
print(f'Classes: {classes}')

images_per_class = len(all_data) // len(classes)
fig, axs = plt.subplots(len(classes), 2, figsize=(6, 4 * len(classes)))

for i, class_name in enumerate(classes):
    index = i * images_per_class
    for j in range(2):
        axs[i, j].set_title(f'{i}. {class_name}')
        axs[i, j].imshow(all_data[index + j])
        axs[i, j].axis('off')

plt.tight_layout()
plt.show()
# Out:
# Classes: ['defective', 'good']

# %% [markdown]
# ## A. Data Loading and Preprocessing

# %%
import torch
from torch.utils.data import DataLoader, TensorDataset, random_split
import numpy as np

num_classes = 2
images_per_class = 10
train_images_per_class = int(images_per_class * 0.8)
val_images_per_class = int(images_per_class * 0.2)

x_train = []
x_val = []

for i in range(num_classes):
    start_index = i * images_per_class
    x_train.extend(all_data[start_index:start_index + train_images_per_class])
    x_val.extend(all_data[start_index + train_images_per_class:start_index + images_per_class])

# The shape changes from (batch_size, height, width, channels) to (batch_size, channels, height, width)
x_train = np.transpose(np.array(x_train), (0, 3, 1, 2))
x_val = np.transpose(np.array(x_val), (0, 3, 1, 2))

y_train = np.concatenate([np.full(train_images_per_class, i) for i in range(num_classes)])
y_val = np.concatenate([np.full(val_images_per_class, i) for i in range(num_classes)])

print(f'Shape of x_train: {x_train.shape}')
print(f'Shape of x_val: {x_val.shape}')
print(f'Shape of y_train: {y_train.shape}')
print(f'Shape of y_val: {y_val.shape}')
# Out:
# Shape of x_train: (16, 3, 1024, 1024)
# Shape of x_val: (4, 3, 1024, 1024)
# Shape of y_train: (16,)
# Shape of y_val: (4,)

# %%
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, Dataset
from PIL import Image

train_transforms = transforms.Compose(
    [
        transforms.Resize((32, 32)),
        transforms.AutoAugment(),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
    ]
)

val_transforms = transforms.Compose(
    [
        transforms.Resize((32, 32)),
        transforms.ToTensor(),
    ]
)

class MyDataset(Dataset):
    def __init__(self, x, y, transform=None):
        self.x = x
        self.y = torch.from_numpy(y).long()
        self.transform = transform

    def __len__(self):
        return len(self.x)

    def __getitem__(self, idx):
        new_x = np.transpose(self.x[idx], (1, 2, 0))
        return self.transform(Image.fromarray(new_x)), self.y[idx]

# %%
batch_size = 32

train_dataset = MyDataset(x_train, y_train, train_transforms)
val_dataset = MyDataset(x_val, y_val, val_transforms)

train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True, num_workers=2, pin_memory=True, persistent_workers=True)
val_loader = DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=False, num_workers=1, pin_memory=True, persistent_workers=True)

# %% [markdown]
# ## B. Defining Neural Networks

# %%
import torch.nn as nn
import torch.nn.functional as F
from torchvision import models

model = models.resnet18(weights='IMAGENET1K_V1')

# ConvNet as fixed feature extractor (freeze parameters)
for param in model.parameters():
    param.requires_grad = False

num_ftrs = model.fc.in_features
num_class = 2

# change # of class from 1000 into 2 in the last layer
model.fc = nn.Linear(num_ftrs, num_class)
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=2, bias=True)
# )

# %% [markdown]
# ## C. Training the Neural Network

# %%
import torch.optim as optim
from torch.optim.lr_scheduler import CosineAnnealingLR, StepLR
from tqdm.auto import tqdm

train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []

epochs = 150
model = model.cuda()

best_val_loss = float('inf')
best_val_acc = -1

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-1)
lr_scheduler = CosineAnnealingLR(optimizer, T_max=len(train_loader)*epochs, eta_min=0)

for epoch in tqdm(range(epochs)):
    # Training
    model.train()
    total_loss = 0.0
    train_correct = 0
    total_train_samples = 0

    for images, labels in train_loader:
        images = images.cuda()
        images = (images) / 255.
        labels = labels.cuda()
        optimizer.zero_grad()
        outputs = model(images)

        labels = labels.long()

        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()

        train_predicted = outputs.argmax(-1)
        train_correct += (train_predicted == labels).sum().item()
        total_train_samples += labels.size(0)

    avg_train_loss = total_loss / len(train_loader)
    train_accuracy = 100. * train_correct / total_train_samples

    # Validation
    model.eval()
    total_val_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in val_loader:
            images = images.cuda()
            images = (images) / 255.
            labels = labels.cuda()
            outputs = model(images)

            labels = labels.long()

            loss = criterion(outputs, labels)
            total_val_loss += loss.item()

            predicted = outputs.argmax(-1)
            correct += (predicted == labels).sum().item()
            total += labels.size(0)

    avg_val_loss = total_val_loss / len(val_loader)
    val_accuracy = 100. * correct / total

    # Learning rate update
    lr_scheduler.step()

    # Checkpoint
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss

    if val_accuracy > best_val_acc:
        best_val_acc = val_accuracy
        torch.save(model.state_dict(), 'model_classification.pth')

    print(f'Epoch {epoch+1}/{epochs}, Train loss: {avg_train_loss:.4f}, Train acc: {train_accuracy:.4f}%, Val loss: {avg_val_loss:.4f}, Val acc: {val_accuracy:.4f}%, Best Val loss: {best_val_loss:.4f} Best Val acc: {best_val_acc:.2f}%')

    # Store performance
    train_losses.append(avg_train_loss)
    train_accuracies.append(train_accuracy)
    val_losses.append(avg_val_loss)
    val_accuracies.append(val_accuracy)
# Out:
#   0%|          | 0/150 [00:00<?, ?it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Epoch 1/150, Train loss: 0.6425, Train acc: 68.7500%, Val loss: 1.8586, Val acc: 50.0000%, Best Val loss: 1.8586 Best Val acc: 50.00%
# Epoch 2/150, Train loss: 23.7246, Train acc: 50.0000%, Val loss: 1.3485, Val acc: 50.0000%, Best Val loss: 1.3485 Best Val acc: 50.00%
# Epoch 3/150, Train loss: 2.4875, Train acc: 56.2500%, Val loss: 4.8777, Val acc: 50.0000%, Best Val loss: 1.3485 Best Val acc: 50.00%
# Epoch 4/150, Train loss: 22.8824, Train acc: 50.0000%, Val loss: 3.9497, Val acc: 50.0000%, Best Val loss: 1.3485 Best Val acc: 50.00%
# Epoch 5/150, Train loss: 12.4574, Train acc: 50.0000%, Val loss: 0.7126, Val acc: 50.0000%, Best Val loss: 0.7126 Best Val acc: 50.00%
# Epoch 6/150, Train loss: 5.5443, Train acc: 56.2500%, Val loss: 2.4450, Val acc: 50.0000%, Best Val loss: 0.7126 Best Val acc: 50.00%
# Epoch 7/150, Train loss: 10.3778, Train acc: 56.2500%, Val loss: 1.4344, Val acc: 50.0000%, Best Val loss: 0.7126 Best Val acc: 50.00%
# Epoch 8/150, Train loss: 12.3268, Train acc: 56.2500%, Val loss: 2.7384, Val acc: 50.0000%, Best Val loss: 0.7126 Best Val acc: 50.00%
# Epoch 9/150, Train loss: 5.6695, Train acc: 31.2500%, Val loss: 7.2093, Val acc: 50.0000%, Best Val loss: 0.7126 Best Val acc: 50.00%
# Epoch 10/150, Train loss: 8.4570, Train acc: 56.2500%, Val loss: 8.4817, Val acc: 50.0000%, Best Val loss: 0.7126 Best Val acc: 50.00%
# Epoch 11/150, Train loss: 11.7435, Train acc: 50.0000%, Val loss: 5.7442, Val acc: 50.0000%, Best Val loss: 0.7126 Best Val acc: 50.00%
# Epoch 12/150, Train loss: 9.8892, Train acc: 37.5000%, Val loss: 1.0016, Val acc: 50.0000%, Best Val loss: 0.7126 Best Val acc: 50.00%
# Epoch 13/150, Train loss: 4.9333, Train acc: 56.2500%, Val loss: 0.9629, Val acc: 50.0000%, Best Val loss: 0.7126 Best Val acc: 50.00%
# Epoch 14/150, Train loss: 5.3868, Train acc: 62.5000%, Val loss: 0.6990, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 15/150, Train loss: 6.7713, Train acc: 50.0000%, Val loss: 4.5351, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 16/150, Train loss: 5.6305, Train acc: 50.0000%, Val loss: 10.3517, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 17/150, Train loss: 2.8823, Train acc: 56.2500%, Val loss: 16.7717, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 18/150, Train loss: 5.4798, Train acc: 68.7500%, Val loss: 19.0040, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 19/150, Train loss: 4.9305, Train acc: 68.7500%, Val loss: 17.1367, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 20/150, Train loss: 4.5938, Train acc: 81.2500%, Val loss: 12.5660, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 21/150, Train loss: 4.4263, Train acc: 56.2500%, Val loss: 6.5603, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 22/150, Train loss: 9.0370, Train acc: 56.2500%, Val loss: 3.3328, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 23/150, Train loss: 2.8722, Train acc: 68.7500%, Val loss: 3.6620, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 24/150, Train loss: 10.0108, Train acc: 37.5000%, Val loss: 4.4769, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 25/150, Train loss: 4.2837, Train acc: 68.7500%, Val loss: 9.2506, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 26/150, Train loss: 2.7315, Train acc: 81.2500%, Val loss: 12.4327, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 27/150, Train loss: 4.3887, Train acc: 68.7500%, Val loss: 11.1100, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 28/150, Train loss: 6.6012, Train acc: 68.7500%, Val loss: 5.3783, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 29/150, Train loss: 2.0979, Train acc: 81.2500%, Val loss: 4.5343, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 30/150, Train loss: 5.2000, Train acc: 62.5000%, Val loss: 15.1536, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 31/150, Train loss: 2.4888, Train acc: 75.0000%, Val loss: 18.5980, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 32/150, Train loss: 8.1540, Train acc: 56.2500%, Val loss: 17.8490, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 33/150, Train loss: 4.7819, Train acc: 62.5000%, Val loss: 16.6049, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 34/150, Train loss: 3.6053, Train acc: 68.7500%, Val loss: 17.4632, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 35/150, Train loss: 2.5009, Train acc: 81.2500%, Val loss: 15.6504, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 36/150, Train loss: 6.4738, Train acc: 56.2500%, Val loss: 19.3260, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 37/150, Train loss: 2.2132, Train acc: 75.0000%, Val loss: 23.2543, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 38/150, Train loss: 5.4399, Train acc: 62.5000%, Val loss: 30.1443, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 39/150, Train loss: 6.4277, Train acc: 50.0000%, Val loss: 26.6348, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 40/150, Train loss: 5.0281, Train acc: 50.0000%, Val loss: 27.9798, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 41/150, Train loss: 1.7824, Train acc: 75.0000%, Val loss: 29.2129, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 42/150, Train loss: 5.7393, Train acc: 56.2500%, Val loss: 31.7220, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 43/150, Train loss: 2.6974, Train acc: 81.2500%, Val loss: 35.0026, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 44/150, Train loss: 2.2382, Train acc: 62.5000%, Val loss: 35.0351, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 45/150, Train loss: 5.2254, Train acc: 62.5000%, Val loss: 39.7687, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 46/150, Train loss: 1.7336, Train acc: 62.5000%, Val loss: 36.6907, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 47/150, Train loss: 1.5566, Train acc: 68.7500%, Val loss: 34.8571, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 48/150, Train loss: 5.2675, Train acc: 56.2500%, Val loss: 36.3109, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 49/150, Train loss: 5.2763, Train acc: 62.5000%, Val loss: 41.3523, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 50/150, Train loss: 3.0804, Train acc: 62.5000%, Val loss: 39.4287, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 51/150, Train loss: 4.1197, Train acc: 62.5000%, Val loss: 47.9425, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 52/150, Train loss: 4.1638, Train acc: 68.7500%, Val loss: 50.4121, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 53/150, Train loss: 3.7520, Train acc: 68.7500%, Val loss: 51.5697, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 54/150, Train loss: 2.1930, Train acc: 62.5000%, Val loss: 43.8852, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 55/150, Train loss: 8.1292, Train acc: 37.5000%, Val loss: 40.7655, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 56/150, Train loss: 1.9221, Train acc: 68.7500%, Val loss: 44.7731, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 57/150, Train loss: 3.2100, Train acc: 75.0000%, Val loss: 43.6498, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 58/150, Train loss: 3.2774, Train acc: 75.0000%, Val loss: 40.6638, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 59/150, Train loss: 6.0100, Train acc: 50.0000%, Val loss: 40.1578, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 60/150, Train loss: 2.9614, Train acc: 62.5000%, Val loss: 41.6577, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 61/150, Train loss: 5.4925, Train acc: 68.7500%, Val loss: 49.9036, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 62/150, Train loss: 3.0349, Train acc: 75.0000%, Val loss: 55.8561, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 63/150, Train loss: 3.6376, Train acc: 75.0000%, Val loss: 50.1050, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 64/150, Train loss: 4.0547, Train acc: 62.5000%, Val loss: 46.3751, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 65/150, Train loss: 4.8187, Train acc: 56.2500%, Val loss: 46.4260, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 66/150, Train loss: 2.0818, Train acc: 81.2500%, Val loss: 40.3417, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 67/150, Train loss: 2.8130, Train acc: 75.0000%, Val loss: 34.5514, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 68/150, Train loss: 4.5785, Train acc: 75.0000%, Val loss: 32.7438, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 69/150, Train loss: 4.4131, Train acc: 81.2500%, Val loss: 33.0211, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 70/150, Train loss: 2.4505, Train acc: 75.0000%, Val loss: 29.0542, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 71/150, Train loss: 6.9757, Train acc: 75.0000%, Val loss: 22.9169, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 72/150, Train loss: 2.7929, Train acc: 75.0000%, Val loss: 24.4020, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 73/150, Train loss: 7.5959, Train acc: 50.0000%, Val loss: 19.8630, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 74/150, Train loss: 4.5305, Train acc: 56.2500%, Val loss: 20.6021, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 75/150, Train loss: 4.6353, Train acc: 62.5000%, Val loss: 20.3858, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 76/150, Train loss: 1.8580, Train acc: 87.5000%, Val loss: 17.9393, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 77/150, Train loss: 5.0940, Train acc: 56.2500%, Val loss: 17.3302, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 78/150, Train loss: 4.4767, Train acc: 56.2500%, Val loss: 13.9743, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 79/150, Train loss: 7.2749, Train acc: 43.7500%, Val loss: 11.6333, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 80/150, Train loss: 1.7769, Train acc: 68.7500%, Val loss: 13.2571, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 81/150, Train loss: 2.5601, Train acc: 56.2500%, Val loss: 11.0551, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 82/150, Train loss: 3.1248, Train acc: 68.7500%, Val loss: 9.5386, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 83/150, Train loss: 2.7669, Train acc: 68.7500%, Val loss: 7.5405, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 84/150, Train loss: 4.0271, Train acc: 62.5000%, Val loss: 6.7062, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 85/150, Train loss: 3.7272, Train acc: 68.7500%, Val loss: 6.3540, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 86/150, Train loss: 3.9205, Train acc: 50.0000%, Val loss: 4.7709, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 87/150, Train loss: 0.7956, Train acc: 81.2500%, Val loss: 2.9327, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 88/150, Train loss: 2.6977, Train acc: 68.7500%, Val loss: 3.2014, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 50.00%
# Epoch 89/150, Train loss: 2.5201, Train acc: 81.2500%, Val loss: 1.3423, Val acc: 75.0000%, Best Val loss: 0.6990 Best Val acc: 75.00%
# Epoch 90/150, Train loss: 2.0073, Train acc: 75.0000%, Val loss: 2.5604, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 75.00%
# Epoch 91/150, Train loss: 2.8777, Train acc: 68.7500%, Val loss: 2.1596, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 75.00%
# Epoch 92/150, Train loss: 1.3452, Train acc: 81.2500%, Val loss: 1.4556, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 75.00%
# Epoch 93/150, Train loss: 6.4118, Train acc: 56.2500%, Val loss: 3.7228, Val acc: 0.0000%, Best Val loss: 0.6990 Best Val acc: 75.00%
# Epoch 94/150, Train loss: 4.6373, Train acc: 68.7500%, Val loss: 4.0793, Val acc: 25.0000%, Best Val loss: 0.6990 Best Val acc: 75.00%
# Epoch 95/150, Train loss: 3.1571, Train acc: 68.7500%, Val loss: 5.7245, Val acc: 25.0000%, Best Val loss: 0.6990 Best Val acc: 75.00%
# Epoch 96/150, Train loss: 0.4940, Train acc: 81.2500%, Val loss: 5.7282, Val acc: 25.0000%, Best Val loss: 0.6990 Best Val acc: 75.00%
# Epoch 97/150, Train loss: 5.2264, Train acc: 56.2500%, Val loss: 6.3597, Val acc: 0.0000%, Best Val loss: 0.6990 Best Val acc: 75.00%
# Epoch 98/150, Train loss: 6.6550, Train acc: 50.0000%, Val loss: 5.5940, Val acc: 0.0000%, Best Val loss: 0.6990 Best Val acc: 75.00%
# Epoch 99/150, Train loss: 7.6565, Train acc: 62.5000%, Val loss: 4.8220, Val acc: 0.0000%, Best Val loss: 0.6990 Best Val acc: 75.00%
# Epoch 100/150, Train loss: 5.7390, Train acc: 62.5000%, Val loss: 5.0762, Val acc: 0.0000%, Best Val loss: 0.6990 Best Val acc: 75.00%
# Epoch 101/150, Train loss: 2.2347, Train acc: 75.0000%, Val loss: 4.6758, Val acc: 0.0000%, Best Val loss: 0.6990 Best Val acc: 75.00%
# Epoch 102/150, Train loss: 0.8408, Train acc: 87.5000%, Val loss: 4.6255, Val acc: 0.0000%, Best Val loss: 0.6990 Best Val acc: 75.00%
# Epoch 103/150, Train loss: 7.4383, Train acc: 31.2500%, Val loss: 2.7786, Val acc: 25.0000%, Best Val loss: 0.6990 Best Val acc: 75.00%
# Epoch 104/150, Train loss: 4.4186, Train acc: 56.2500%, Val loss: 2.0174, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 75.00%
# Epoch 105/150, Train loss: 3.1461, Train acc: 75.0000%, Val loss: 4.5388, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 75.00%
# Epoch 106/150, Train loss: 2.2629, Train acc: 75.0000%, Val loss: 3.4364, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 75.00%
# Epoch 107/150, Train loss: 7.8374, Train acc: 56.2500%, Val loss: 4.7543, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 75.00%
# Epoch 108/150, Train loss: 3.5418, Train acc: 62.5000%, Val loss: 3.3483, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 75.00%
# Epoch 109/150, Train loss: 2.2092, Train acc: 56.2500%, Val loss: 2.5714, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 75.00%
# Epoch 110/150, Train loss: 4.4754, Train acc: 56.2500%, Val loss: 2.6289, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 75.00%
# Epoch 111/150, Train loss: 3.4165, Train acc: 68.7500%, Val loss: 0.9616, Val acc: 50.0000%, Best Val loss: 0.6990 Best Val acc: 75.00%
# Epoch 112/150, Train loss: 1.3134, Train acc: 81.2500%, Val loss: 0.4287, Val acc: 75.0000%, Best Val loss: 0.4287 Best Val acc: 75.00%
# Epoch 113/150, Train loss: 3.7117, Train acc: 68.7500%, Val loss: 1.0962, Val acc: 50.0000%, Best Val loss: 0.4287 Best Val acc: 75.00%
# Epoch 114/150, Train loss: 4.1837, Train acc: 56.2500%, Val loss: 1.0433, Val acc: 75.0000%, Best Val loss: 0.4287 Best Val acc: 75.00%
# Epoch 115/150, Train loss: 2.0324, Train acc: 68.7500%, Val loss: 0.8648, Val acc: 75.0000%, Best Val loss: 0.4287 Best Val acc: 75.00%
# Epoch 116/150, Train loss: 3.1580, Train acc: 62.5000%, Val loss: 1.7580, Val acc: 50.0000%, Best Val loss: 0.4287 Best Val acc: 75.00%
# Epoch 117/150, Train loss: 1.5119, Train acc: 75.0000%, Val loss: 1.1916, Val acc: 50.0000%, Best Val loss: 0.4287 Best Val acc: 75.00%
# Epoch 118/150, Train loss: 4.2388, Train acc: 62.5000%, Val loss: 1.8672, Val acc: 50.0000%, Best Val loss: 0.4287 Best Val acc: 75.00%
# Epoch 119/150, Train loss: 2.1637, Train acc: 68.7500%, Val loss: 2.2737, Val acc: 50.0000%, Best Val loss: 0.4287 Best Val acc: 75.00%
# Epoch 120/150, Train loss: 3.2644, Train acc: 68.7500%, Val loss: 3.8056, Val acc: 50.0000%, Best Val loss: 0.4287 Best Val acc: 75.00%
# Epoch 121/150, Train loss: 4.8391, Train acc: 56.2500%, Val loss: 4.0661, Val acc: 50.0000%, Best Val loss: 0.4287 Best Val acc: 75.00%
# Epoch 122/150, Train loss: 1.0937, Train acc: 81.2500%, Val loss: 3.4033, Val acc: 50.0000%, Best Val loss: 0.4287 Best Val acc: 75.00%
# Epoch 123/150, Train loss: 5.8405, Train acc: 62.5000%, Val loss: 2.5531, Val acc: 50.0000%, Best Val loss: 0.4287 Best Val acc: 75.00%
# Epoch 124/150, Train loss: 0.8801, Train acc: 75.0000%, Val loss: 1.4945, Val acc: 50.0000%, Best Val loss: 0.4287 Best Val acc: 75.00%
# Epoch 125/150, Train loss: 3.6239, Train acc: 81.2500%, Val loss: 1.7484, Val acc: 50.0000%, Best Val loss: 0.4287 Best Val acc: 75.00%
# Epoch 126/150, Train loss: 2.8573, Train acc: 62.5000%, Val loss: 1.7204, Val acc: 50.0000%, Best Val loss: 0.4287 Best Val acc: 75.00%
# Epoch 127/150, Train loss: 4.5939, Train acc: 68.7500%, Val loss: 1.2567, Val acc: 50.0000%, Best Val loss: 0.4287 Best Val acc: 75.00%
# Epoch 128/150, Train loss: 2.0806, Train acc: 75.0000%, Val loss: 0.3958, Val acc: 75.0000%, Best Val loss: 0.3958 Best Val acc: 75.00%
# Epoch 129/150, Train loss: 2.1625, Train acc: 81.2500%, Val loss: 1.2619, Val acc: 50.0000%, Best Val loss: 0.3958 Best Val acc: 75.00%
# Epoch 130/150, Train loss: 6.5578, Train acc: 62.5000%, Val loss: 1.8479, Val acc: 50.0000%, Best Val loss: 0.3958 Best Val acc: 75.00%
# Epoch 131/150, Train loss: 3.6480, Train acc: 62.5000%, Val loss: 1.8740, Val acc: 50.0000%, Best Val loss: 0.3958 Best Val acc: 75.00%
# Epoch 132/150, Train loss: 2.1748, Train acc: 75.0000%, Val loss: 1.5168, Val acc: 50.0000%, Best Val loss: 0.3958 Best Val acc: 75.00%
# Epoch 133/150, Train loss: 4.7295, Train acc: 62.5000%, Val loss: 1.7861, Val acc: 50.0000%, Best Val loss: 0.3958 Best Val acc: 75.00%
# Epoch 134/150, Train loss: 0.8419, Train acc: 68.7500%, Val loss: 1.6003, Val acc: 50.0000%, Best Val loss: 0.3958 Best Val acc: 75.00%
# Epoch 135/150, Train loss: 2.6919, Train acc: 68.7500%, Val loss: 0.6914, Val acc: 75.0000%, Best Val loss: 0.3958 Best Val acc: 75.00%
# Epoch 136/150, Train loss: 3.4852, Train acc: 62.5000%, Val loss: 0.8001, Val acc: 75.0000%, Best Val loss: 0.3958 Best Val acc: 75.00%
# Epoch 137/150, Train loss: 6.1129, Train acc: 62.5000%, Val loss: 0.9329, Val acc: 50.0000%, Best Val loss: 0.3958 Best Val acc: 75.00%
# Epoch 138/150, Train loss: 4.5427, Train acc: 37.5000%, Val loss: 1.4018, Val acc: 50.0000%, Best Val loss: 0.3958 Best Val acc: 75.00%
# Epoch 139/150, Train loss: 3.2790, Train acc: 68.7500%, Val loss: 1.3762, Val acc: 50.0000%, Best Val loss: 0.3958 Best Val acc: 75.00%
# Epoch 140/150, Train loss: 2.1875, Train acc: 62.5000%, Val loss: 2.1903, Val acc: 50.0000%, Best Val loss: 0.3958 Best Val acc: 75.00%
# Epoch 141/150, Train loss: 1.8190, Train acc: 75.0000%, Val loss: 2.1349, Val acc: 50.0000%, Best Val loss: 0.3958 Best Val acc: 75.00%
# Epoch 142/150, Train loss: 2.3307, Train acc: 62.5000%, Val loss: 2.3152, Val acc: 50.0000%, Best Val loss: 0.3958 Best Val acc: 75.00%
# Epoch 143/150, Train loss: 0.3176, Train acc: 87.5000%, Val loss: 3.6422, Val acc: 50.0000%, Best Val loss: 0.3958 Best Val acc: 75.00%
# Epoch 144/150, Train loss: 1.8861, Train acc: 68.7500%, Val loss: 3.6119, Val acc: 50.0000%, Best Val loss: 0.3958 Best Val acc: 75.00%
# Epoch 145/150, Train loss: 3.2472, Train acc: 56.2500%, Val loss: 3.7476, Val acc: 50.0000%, Best Val loss: 0.3958 Best Val acc: 75.00%
# Epoch 146/150, Train loss: 1.4868, Train acc: 75.0000%, Val loss: 4.0195, Val acc: 50.0000%, Best Val loss: 0.3958 Best Val acc: 75.00%
# Epoch 147/150, Train loss: 1.1476, Train acc: 68.7500%, Val loss: 3.8655, Val acc: 50.0000%, Best Val loss: 0.3958 Best Val acc: 75.00%
# Epoch 148/150, Train loss: 1.7906, Train acc: 81.2500%, Val loss: 3.3641, Val acc: 50.0000%, Best Val loss: 0.3958 Best Val acc: 75.00%
# Epoch 149/150, Train loss: 2.8333, Train acc: 62.5000%, Val loss: 2.3067, Val acc: 75.0000%, Best Val loss: 0.3958 Best Val acc: 75.00%
# Epoch 150/150, Train loss: 3.8201, Train acc: 75.0000%, Val loss: 2.1714, Val acc: 75.0000%, Best Val loss: 0.3958 Best Val acc: 75.00%

# %% [markdown]
# ### Visualizing model performance

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 2, figsize=(15, 5))

# Plotting training and validation accuracy
ax[0].plot(train_accuracies)
ax[0].plot(val_accuracies)
ax[0].set_title('Model Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].legend(['Train', 'Val'])

# Plotting training and validation loss
ax[1].plot(train_losses)
ax[1].plot(val_losses)
ax[1].set_title('Model Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(['Train', 'Val'])

plt.show()

# %% [markdown]
# ## D. Evaluating Your Trained Model

# %% [markdown]
# ### Load Trained Model and Evaluate

# %%
# Load the trained weights
model.load_state_dict(torch.load('model_classification.pth'))

# Set the model to evaluation mode
model.eval()

test_correct = 0
test_total = 0

with torch.no_grad():
    for images, labels in val_loader:

        images = images.cuda()
        images = (images) / 255.

        labels = labels.cuda()
        labels = labels.long()

        outputs = model(images)

        predicted = outputs.argmax(-1)
        print(predicted)
        print(labels)
        test_correct += (predicted == labels).sum().item()
        test_total += labels.size(0)

print(f'Test accuracy is {100. * test_correct / test_total}%')
# Out:
# tensor([1, 0, 1, 1], device='cuda:0')
# tensor([0, 0, 1, 1], device='cuda:0')
# Test accuracy is 75.0%
